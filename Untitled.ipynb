# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename='/home/abu/Documents/learn/robotics/sample.jpg'

# %%
img=mpimg.imread(filename)

# %%
plt.imshow(img)

# %%
import numpy as np

# %%
print(img.dtype,img.shape,np.min(img),np.max(img))
# Out:
# uint8 (160, 320, 3) 0 255

# %%
red_channel=np.copy(img)
green_channel=np.copy(img)
blue_channel=np.copy(img)

# %%
red_channel[:,:,1:2]=0
green_channel[:,:,[0,2]]=0
blue_channel[:,:,[0,1]]=0

# %%
fig=plt.figure(figsize=(36,9))

# %%
plt.subplot(131)
plt.imshow(red_channel)
plt.subplot(132)
plt.imshow(green_channel)
plt.subplot(133)
plt.imshow(blue_channel)
plt.show()
